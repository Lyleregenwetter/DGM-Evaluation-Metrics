# %% [markdown]
# **Using Evaluation Utils**:
#
# In this notebook, we discuss how to use the provided utilities file to compare models on numerous metrics on different problems at the same time

# %%
import evaluation
import load_data
import Padgan_variants
import utils
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import Padgan_variants
import VAEs
# Out:
# C:\Users\Lyle\Documents\DeCoDE\DGM-Evaluation-Metrics\Padgan_variants.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# **Setting up DGMS**:
#
# Let's create a pandas series with several DGMs

# %%
reg_clf_params = None
config_params = [False, False, False, None, None, False]
train_params = [128, 1e-3, 1e-3, 1, 0, 4, 2000] #Setting DPP weight to 0 for normal GAN
DTAI_params= [None, None, None]

methods=pd.Series()
methods["GAN"] = Padgan_variants.padgan_wrapper(config_params, train_params, DTAI_params, reg_clf_params, reg_clf_params)
methods["VAE"] = VAEs.VAE_wrapper([100, 128, 1e-3, 4, .05, False])
# Out:
# C:\Users\Lyle\AppData\Local\Temp\ipykernel_19284\2405019141.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   methods=pd.Series()

# %% [markdown]
# **Setting up Problems**
#
# The utilities provided expect each function to be specified as a list of the following components:
# - Sampling function
# - Validity test
# - Objectives
# - Plotting Range
# - Conditioning Function
# - Condition Value
#
# Unused components can be left as None

# %%
functions=[]

DM_val = load_data.all_val_wrapper()

pareto = np.stack([0.4705*np.linspace(0,1,1000), 0.4705*np.linspace(1,0,1000)], axis=1)
sampling_func_1 = load_data.sample_circle_blobs_wrapper(10000, 0, 6, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples
sampling_func_2 = load_data.sample_circle_blobs_wrapper(10000, 0, 2, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples

rangearr = np.array([[-2,2], [-2,2]])

functions.append([sampling_func_1, DM_val, None, rangearr, None, None])
functions.append([sampling_func_2, DM_val, None, rangearr, None, None])

# %% [markdown]
# **Setting Up Metrics**:
# We set up the metrics we want to evaluate in a pandas series.
# Each entry consists of:
# metrics["name"] = ["direction", metric wrapper]
#
# - name is a name you are assigning to the metrics
# - direction is either "minimize" or "maximize"
# - metric wrapper is the a wrapper function of the desired metric with any hyperparameters specified

# %%
metrics=pd.Series()
metrics["Nearest Dataset Sample"] = ["minimize", evaluation.gen_data_distance_wrapper("x", "min")]
metrics["Nearest Generated Sample"] = ["minimize", evaluation.data_gen_distance_wrapper("x", "min")]
metrics["F1"] = ["maximize", evaluation.F_wrapper("x", 1)]
metrics["F10"] = ["maximize", evaluation.F_wrapper("x", 10)]
metrics["F0.1"] = ["maximize", evaluation.F_wrapper("x", 0.1)]
metrics["AUC-PR"] = ["maximize", evaluation.AUC_wrapper("x")]
metrics["MMD"] = ["minimize", evaluation.MMD_wrapper("x")]
# Out:
# C:\Users\Lyle\AppData\Local\Temp\ipykernel_19284\3187865464.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   metrics=pd.Series()

# %% [markdown]
# **General Parameters**
#
# We set up some flags and general settings:

# %%
numgen = 1000 #Number of samples to generate
numanim = 5 #Number of intermediate training steps to animate and use for training plots
numinst = 3 #Number of instantiations to test
scaling = True #Scale or not
scorebars = True #Print progress for scoring functions

np.random.seed(0)

validity_status = 0 #whether we are considering constraints
obj_status = 0 #whether we are considering functional performance
conditional_status = 0 #whether we are considering conditioning
cond_dist=False #Whether conditional metrics are compared against conditional or marginal distribution

# %% [markdown]
# **fit_and_generate**
# We call fit_and_generate from the utilities file to generate the datasets and train the models.
# fit_and_generate takes:
# - functions: Our list of functions defined earlier
# - methods: Our list of methods defined earlier
# - numinst: How many model instantiations to test
# - numgen: How many points to sample from each generated model
# - scaling: Whether to scale the datasets before training
# - obj_status: #wheteher we are considering functional performance
# - conditional_status: Whether we are considering conditioning
# - holdout: fraction of dataset to hold out during training (used for rediscovery)
#
# The fit_and_generate function returns a timestamp in a string corresponding to the folder in which the results are saved.

# %%
timestr = utils.fit_and_generate(functions, methods, numinst, numanim, numgen, scaling, obj_status, conditional_status, 0)
# Out:
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_0_Instance_0_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_0_Instance_0_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_0_Instance_0_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_0_Instance_0_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_1_Instance_0_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_1_Instance_0_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_1_Instance_0_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_1_Instance_0_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_0_Instance_1_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_0_Instance_1_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_0_Instance_1_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_0_Instance_1_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_1_Instance_1_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_1_Instance_1_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_1_Instance_1_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_1_Instance_1_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_0_Instance_2_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_0_Instance_2_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_0_Instance_2_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_0_Instance_2_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_1_Instance_2_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/GAN_Problem_1_Instance_2_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_1_Instance_2_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200253/Models/VAE_Problem_1_Instance_2_decoder\assets
# [array([ 400,  800, 1200, 1600, 2000]), array([ 20,  40,  60,  80, 100])]

# %% [markdown]
# **score**:
# Next, we score the generated models. The scroring utilities function takes:
# - timestr: the timestring corresponding to the results we want to evaluate
# - functions: Our list of functions defined earlier
# - methods: Our list of methods defined earlier
# - metrics: The metrics to test
# - numinst: How many model instantiations to test
# - scaling: Whether to scale the datasets before training
# - cond_dist: Whether conditional metrics are compared against conditional or marginal distribution
# - scorebars: Whether to print progress bars/ evaluation status
#
# score saves scores in the folder indicated by timestr.

# %%
import importlib
importlib.reload(evaluation)
importlib.reload(utils)
# Out:
# <module 'utils' from 'C:\\Users\\Lyle\\Documents\\DeCoDE\\DGM-Evaluation-Metrics\\utils.py'>

# %%
utils.score(timestr, functions, methods, metrics, numinst, scaling, cond_dist, scorebars, plotscores=True)
# Out:
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.21it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  8.29it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.17it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.77it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.62it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.81it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.43it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.71it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.48it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.48it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.15it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.46it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.75it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.93it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.47it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.97it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.79it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.80it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.00it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.54it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.85it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.77it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.69it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.69it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.46it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.81it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.81it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.76it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.89it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.81it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.57it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.71it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.27it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.94it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.83it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.31it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.39it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.96it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.79it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.75it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.51it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  8.11it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.70it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.95it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.98it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.13it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.37it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.13it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.38it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.26it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.85it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.15it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.27it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.82it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.78it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.46it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.79it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.37it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.70it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.15it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# <style type="text/css">
# #T_e7cee_row0_col0, #T_e7cee_row1_col0, #T_e7cee_row2_col0, #T_e7cee_row3_col0, #T_e7cee_row4_col0, #T_e7cee_row5_col0, #T_e7cee_row6_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_e7cee">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 1 Scores:</th>
#       <th id="T_e7cee_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_e7cee_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7cee_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_e7cee_row0_col0" class="data row0 col0" >0.014±0.001</td>
#       <td id="T_e7cee_row0_col1" class="data row0 col1" >0.206±0.025</td>
#     </tr>
#     <tr>
#       <th id="T_e7cee_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_e7cee_row1_col0" class="data row1 col0" >0.076±0.005</td>
#       <td id="T_e7cee_row1_col1" class="data row1 col1" >0.198±0.023</td>
#     </tr>
#     <tr>
#       <th id="T_e7cee_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_e7cee_row2_col0" class="data row2 col0" >0.650±0.097</td>
#       <td id="T_e7cee_row2_col1" class="data row2 col1" >0.160±0.019</td>
#     </tr>
#     <tr>
#       <th id="T_e7cee_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_e7cee_row3_col0" class="data row3 col0" >0.964±0.006</td>
#       <td id="T_e7cee_row3_col1" class="data row3 col1" >0.333±0.025</td>
#     </tr>
#     <tr>
#       <th id="T_e7cee_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_e7cee_row4_col0" class="data row4 col0" >0.914±0.042</td>
#       <td id="T_e7cee_row4_col1" class="data row4 col1" >0.545±0.029</td>
#     </tr>
#     <tr>
#       <th id="T_e7cee_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_e7cee_row5_col0" class="data row5 col0" >0.719±0.106</td>
#       <td id="T_e7cee_row5_col1" class="data row5 col1" >0.081±0.014</td>
#     </tr>
#     <tr>
#       <th id="T_e7cee_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_e7cee_row6_col0" class="data row6 col0" >0.003±0.001</td>
#       <td id="T_e7cee_row6_col1" class="data row6 col1" >0.233±0.018</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2b685_row0_col0, #T_2b685_row1_col0, #T_2b685_row2_col0, #T_2b685_row3_col0, #T_2b685_row4_col0, #T_2b685_row5_col0, #T_2b685_row6_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_2b685">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 2 Scores:</th>
#       <th id="T_2b685_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_2b685_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b685_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_2b685_row0_col0" class="data row0 col0" >0.019±0.003</td>
#       <td id="T_2b685_row0_col1" class="data row0 col1" >0.187±0.014</td>
#     </tr>
#     <tr>
#       <th id="T_2b685_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_2b685_row1_col0" class="data row1 col0" >0.059±0.004</td>
#       <td id="T_2b685_row1_col1" class="data row1 col1" >0.268±0.022</td>
#     </tr>
#     <tr>
#       <th id="T_2b685_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_2b685_row2_col0" class="data row2 col0" >0.909±0.023</td>
#       <td id="T_2b685_row2_col1" class="data row2 col1" >0.405±0.037</td>
#     </tr>
#     <tr>
#       <th id="T_2b685_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_2b685_row3_col0" class="data row3 col0" >0.992±0.007</td>
#       <td id="T_2b685_row3_col1" class="data row3 col1" >0.346±0.039</td>
#     </tr>
#     <tr>
#       <th id="T_2b685_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_2b685_row4_col0" class="data row4 col0" >0.990±0.004</td>
#       <td id="T_2b685_row4_col1" class="data row4 col1" >0.769±0.022</td>
#     </tr>
#     <tr>
#       <th id="T_2b685_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_2b685_row5_col0" class="data row5 col0" >0.972±0.015</td>
#       <td id="T_2b685_row5_col1" class="data row5 col1" >0.264±0.034</td>
#     </tr>
#     <tr>
#       <th id="T_2b685_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_2b685_row6_col0" class="data row6 col0" >0.004±0.003</td>
#       <td id="T_2b685_row6_col1" class="data row6 col1" >0.189±0.012</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_84073_row0_col0, #T_84073_row1_col0, #T_84073_row2_col0, #T_84073_row3_col0, #T_84073_row4_col0, #T_84073_row5_col0, #T_84073_row6_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_84073">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Average scores:</th>
#       <th id="T_84073_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_84073_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84073_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_84073_row0_col0" class="data row0 col0" >0.017±0.004</td>
#       <td id="T_84073_row0_col1" class="data row0 col1" >0.197±0.023</td>
#     </tr>
#     <tr>
#       <th id="T_84073_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_84073_row1_col0" class="data row1 col0" >0.067±0.010</td>
#       <td id="T_84073_row1_col1" class="data row1 col1" >0.233±0.042</td>
#     </tr>
#     <tr>
#       <th id="T_84073_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_84073_row2_col0" class="data row2 col0" >0.780±0.148</td>
#       <td id="T_84073_row2_col1" class="data row2 col1" >0.282±0.126</td>
#     </tr>
#     <tr>
#       <th id="T_84073_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_84073_row3_col0" class="data row3 col0" >0.978±0.015</td>
#       <td id="T_84073_row3_col1" class="data row3 col1" >0.339±0.033</td>
#     </tr>
#     <tr>
#       <th id="T_84073_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_84073_row4_col0" class="data row4 col0" >0.952±0.048</td>
#       <td id="T_84073_row4_col1" class="data row4 col1" >0.657±0.115</td>
#     </tr>
#     <tr>
#       <th id="T_84073_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_84073_row5_col0" class="data row5 col0" >0.845±0.147</td>
#       <td id="T_84073_row5_col1" class="data row5 col1" >0.172±0.095</td>
#     </tr>
#     <tr>
#       <th id="T_84073_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_84073_row6_col0" class="data row6 col0" >0.004±0.002</td>
#       <td id="T_84073_row6_col1" class="data row6 col1" >0.211±0.027</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **plot_all**:
# Next, we plot the generated distributions. The plotting function takes:
#
# - timestr: the timestring corresponding to the results we want to evaluate
# - functions: Our list of functions defined earlier
# - methods: Our list of methods defined earlier
# - numinst: How many model instantiations to test
# - scaling: Whether to scale the datasets before training
# - validity_status:whether we are considering constraints
# - obj_status: whether we are considering functional performance
# - conditional_status: whether we are considering conditioning
# - cond_dist: Whether conditional metrics are compared against conditional or marginal distribution
#
# plot saves plots in the folder indicated by timestr. If numinst is greater than 1, saves an animation of the plots
#
# **NOTE: PLOTTING FUNCTIONALITY IS ONLY BUILT FOR 2D PROBLEMS!**

# %%
utils.plot_all(timestr, functions, methods, numinst, scaling, validity_status, obj_status, conditional_status, cond_dist, "red")

# %% [markdown]
# **Special Metrics**
#
# When working with a few special types of metrics we must do some special setup. For rediscovery, we must designate a holdout fraction which we pass to fit_and_generate. For ML efficacy, we must include an auxiliary predictive task. In this case, we encode this predictive task in an objective function. Objectives are also used when considering performance attributes of designs.

# %%
#Rediscovery needs special handling in the utils file. 
#We pass in a special flag: "Rediscovery" to trigger this handling. See utils file for more info
metrics["Rediscovery"] = ["minimize", "Rediscovery", evaluation.data_gen_distance_wrapper("x", "min")]
holdout = 0.05 #If using rediscovery, we need to hold out a portion of the data during training

from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import r2_score

metrics["ML Efficacy"] = ["maximize", evaluation.ML_efficacy_wrapper(KNeighborsRegressor(n_neighbors=5), r2_score)]

# %%
print(metrics)
# Out:
# Nearest Dataset Sample      [minimize, <function gen_data_distance_wrapper...
# Nearest Generated Sample    [minimize, <function data_gen_distance_wrapper...
# F1                          [maximize, <function F_wrapper.<locals>.calc_p...
# F10                         [maximize, <function F_wrapper.<locals>.calc_p...
# F0.1                        [maximize, <function F_wrapper.<locals>.calc_p...
# AUC-PR                      [maximize, <function AUC_wrapper.<locals>.calc...
# MMD                         [minimize, <function MMD_wrapper.<locals>.MMD ...
# Rediscovery                 [minimize, Rediscovery, <function data_gen_dis...
# ML Efficacy                 [maximize, <function ML_efficacy_wrapper.<loca...
# dtype: object

# %%
functions=[]

DM_val = load_data.all_val_wrapper()

#In this case, we include objectives specifically for ML efficacy
DM_objs = [load_data.KNO1_a_wrapper(4,4), load_data.KNO1_b_wrapper(4,4)] 

pareto = np.stack([0.4705*np.linspace(0,1,1000), 0.4705*np.linspace(1,0,1000)], axis=1)
sampling_func_1 = load_data.sample_circle_blobs_wrapper(10000, 0, 6, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples
sampling_func_2 = load_data.sample_circle_blobs_wrapper(10000, 0, 2, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples

rangearr = np.array([[-2,2], [-2,2]])

functions.append([sampling_func_1, DM_val, DM_objs, rangearr, None, None])
functions.append([sampling_func_2, DM_val, DM_objs, rangearr, None, None])

# %%
timestr = utils.fit_and_generate(functions, methods, numinst, numanim, numgen, scaling, obj_status, conditional_status, holdout)
# Out:
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_0_Instance_0_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_0_Instance_0_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_0_Instance_0_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_0_Instance_0_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_1_Instance_0_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_1_Instance_0_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_1_Instance_0_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_1_Instance_0_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_0_Instance_1_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_0_Instance_1_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_0_Instance_1_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_0_Instance_1_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_1_Instance_1_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_1_Instance_1_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_1_Instance_1_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_1_Instance_1_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_0_Instance_2_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_0_Instance_2_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_0_Instance_2_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_0_Instance_2_decoder\assets
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/2000 [00:00<?, ?it/s]
# [128, 2]
# [128, 6]
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_1_Instance_2_generator\assets
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/GAN_Problem_1_Instance_2_discriminator\assets
# VAE Training::   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_1_Instance_2_encoder\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Results/20230726-200715/Models/VAE_Problem_1_Instance_2_decoder\assets
# [array([ 400,  800, 1200, 1600, 2000]), array([ 20,  40,  60,  80, 100])]

# %% [markdown]
# If we want to generate bar plots of our scores, we can pass the plotscores parameter to the scoring function. Note: Scores will be plotted on the same axis, so may need to be scaled.

# %%
import importlib
importlib.reload(utils)
utils.score(timestr, functions, methods, metrics, numinst, scaling, cond_dist, scorebars, plotscores=True)
# Out:
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.57it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.04it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.51it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.11it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.68it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.24it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.67it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.22it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.02it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.64it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.32it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.34it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.91it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.38it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.51it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.04it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.23it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.39it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.45it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.38it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.46it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.53it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.44it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.43it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.19it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.99it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.19it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.46it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.77it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.36it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.30it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.29it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.23it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.46it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.09it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.59it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.86it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.00it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.77it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.85it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.85it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  7.09it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.52it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.26it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.35it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.76it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.31it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.11it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.68it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.10it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.19it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.45it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.68it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.96it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.02it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.66it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  6.59it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.64it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.88it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|=====================================================| 5/5 [00:00<00:00,  5.60it/s]
# Calculating F10
# Calculating F0.1
# Calculating AUC
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# <style type="text/css">
# #T_07e7e_row0_col0, #T_07e7e_row1_col0, #T_07e7e_row2_col0, #T_07e7e_row3_col0, #T_07e7e_row4_col0, #T_07e7e_row5_col0, #T_07e7e_row6_col0, #T_07e7e_row7_col0, #T_07e7e_row8_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_07e7e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 1 Scores:</th>
#       <th id="T_07e7e_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_07e7e_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07e7e_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_07e7e_row0_col0" class="data row0 col0" >0.018±0.007</td>
#       <td id="T_07e7e_row0_col1" class="data row0 col1" >0.205±0.029</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_07e7e_row1_col0" class="data row1 col0" >0.092±0.006</td>
#       <td id="T_07e7e_row1_col1" class="data row1 col1" >0.225±0.031</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_07e7e_row2_col0" class="data row2 col0" >0.526±0.129</td>
#       <td id="T_07e7e_row2_col1" class="data row2 col1" >0.136±0.013</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_07e7e_row3_col0" class="data row3 col0" >0.952±0.023</td>
#       <td id="T_07e7e_row3_col1" class="data row3 col1" >0.351±0.037</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_07e7e_row4_col0" class="data row4 col0" >0.843±0.035</td>
#       <td id="T_07e7e_row4_col1" class="data row4 col1" >0.494±0.041</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_07e7e_row5_col0" class="data row5 col0" >0.583±0.140</td>
#       <td id="T_07e7e_row5_col1" class="data row5 col1" >0.068±0.011</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_07e7e_row6_col0" class="data row6 col0" >0.006±0.004</td>
#       <td id="T_07e7e_row6_col1" class="data row6 col1" >0.235±0.012</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row7" class="row_heading level0 row7" >Rediscovery</th>
#       <td id="T_07e7e_row7_col0" class="data row7 col0" >0.092±0.015</td>
#       <td id="T_07e7e_row7_col1" class="data row7 col1" >0.163±0.028</td>
#     </tr>
#     <tr>
#       <th id="T_07e7e_level0_row8" class="row_heading level0 row8" >ML Efficacy</th>
#       <td id="T_07e7e_row8_col0" class="data row8 col0" >0.786±0.062</td>
#       <td id="T_07e7e_row8_col1" class="data row8 col1" >0.506±0.037</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b4785_row0_col0, #T_b4785_row1_col0, #T_b4785_row2_col0, #T_b4785_row3_col0, #T_b4785_row4_col0, #T_b4785_row5_col0, #T_b4785_row6_col0, #T_b4785_row7_col0, #T_b4785_row8_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_b4785">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 2 Scores:</th>
#       <th id="T_b4785_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_b4785_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4785_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_b4785_row0_col0" class="data row0 col0" >0.023±0.004</td>
#       <td id="T_b4785_row0_col1" class="data row0 col1" >0.178±0.004</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_b4785_row1_col0" class="data row1 col0" >0.070±0.014</td>
#       <td id="T_b4785_row1_col1" class="data row1 col1" >0.247±0.009</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_b4785_row2_col0" class="data row2 col0" >0.891±0.027</td>
#       <td id="T_b4785_row2_col1" class="data row2 col1" >0.455±0.029</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_b4785_row3_col0" class="data row3 col0" >0.991±0.005</td>
#       <td id="T_b4785_row3_col1" class="data row3 col1" >0.416±0.038</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_b4785_row4_col0" class="data row4 col0" >0.989±0.004</td>
#       <td id="T_b4785_row4_col1" class="data row4 col1" >0.802±0.015</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_b4785_row5_col0" class="data row5 col0" >0.964±0.017</td>
#       <td id="T_b4785_row5_col1" class="data row5 col1" >0.323±0.024</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_b4785_row6_col0" class="data row6 col0" >0.008±0.002</td>
#       <td id="T_b4785_row6_col1" class="data row6 col1" >0.175±0.010</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row7" class="row_heading level0 row7" >Rediscovery</th>
#       <td id="T_b4785_row7_col0" class="data row7 col0" >0.188±0.042</td>
#       <td id="T_b4785_row7_col1" class="data row7 col1" >0.234±0.060</td>
#     </tr>
#     <tr>
#       <th id="T_b4785_level0_row8" class="row_heading level0 row8" >ML Efficacy</th>
#       <td id="T_b4785_row8_col0" class="data row8 col0" >0.543±0.151</td>
#       <td id="T_b4785_row8_col1" class="data row8 col1" >0.344±0.106</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_555ed_row0_col0, #T_555ed_row1_col0, #T_555ed_row2_col0, #T_555ed_row3_col0, #T_555ed_row4_col0, #T_555ed_row5_col0, #T_555ed_row6_col0, #T_555ed_row7_col0, #T_555ed_row8_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_555ed">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Average scores:</th>
#       <th id="T_555ed_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_555ed_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_555ed_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_555ed_row0_col0" class="data row0 col0" >0.020±0.006</td>
#       <td id="T_555ed_row0_col1" class="data row0 col1" >0.191±0.025</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_555ed_row1_col0" class="data row1 col0" >0.081±0.015</td>
#       <td id="T_555ed_row1_col1" class="data row1 col1" >0.236±0.026</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_555ed_row2_col0" class="data row2 col0" >0.708±0.205</td>
#       <td id="T_555ed_row2_col1" class="data row2 col1" >0.295±0.161</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_555ed_row3_col0" class="data row3 col0" >0.972±0.026</td>
#       <td id="T_555ed_row3_col1" class="data row3 col1" >0.384±0.050</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_555ed_row4_col0" class="data row4 col0" >0.916±0.077</td>
#       <td id="T_555ed_row4_col1" class="data row4 col1" >0.648±0.157</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_555ed_row5_col0" class="data row5 col0" >0.773±0.215</td>
#       <td id="T_555ed_row5_col1" class="data row5 col1" >0.195±0.129</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_555ed_row6_col0" class="data row6 col0" >0.007±0.003</td>
#       <td id="T_555ed_row6_col1" class="data row6 col1" >0.205±0.032</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row7" class="row_heading level0 row7" >Rediscovery</th>
#       <td id="T_555ed_row7_col0" class="data row7 col0" >0.140±0.058</td>
#       <td id="T_555ed_row7_col1" class="data row7 col1" >0.198±0.059</td>
#     </tr>
#     <tr>
#       <th id="T_555ed_level0_row8" class="row_heading level0 row8" >ML Efficacy</th>
#       <td id="T_555ed_row8_col0" class="data row8 col0" >0.664±0.168</td>
#       <td id="T_555ed_row8_col1" class="data row8 col1" >0.425±0.113</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Other Use Cases**
#
# In this notebook, we have demonstrated how to evaluate numerous models on numerous problems in a distribution-matching setting. To evaluate models for other types of problems, such as diversity, constraint satisfaction, performance, and conditioning, please refer to Notebook 3.
