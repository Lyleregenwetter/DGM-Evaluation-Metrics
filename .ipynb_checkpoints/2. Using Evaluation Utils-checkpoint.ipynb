# %% [markdown]
# **Using Evaluation Utils**:
#
# In this notebook, we discuss how to use the provided utilities file to compare models on numerous metrics on different problems at the same time

# %%
import evaluation
import load_data
import Padgan_variants
import utils
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import Padgan_variants
import VAEs

# %% [markdown]
# **Setting up DGMS**:
#
# Let's create a pandas series with several DGMs

# %%
reg_clf_params = None
config_params = [False, False, False, None, None, False]
train_params = [1, 0, 4, 5000] #Setting DPP weight to 0 for normal GAN
DTAI_params= [None, None, None]

methods=pd.Series()
methods["GAN"] = Padgan_variants.padgan_wrapper(config_params, train_params, DTAI_params, reg_clf_params, reg_clf_params)
methods["VAE"] = VAEs.VAE_wrapper([100, 128, 1e-3, 4, .05, False])
# Out:
# /tmp/ipykernel_24255/4055154814.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   methods=pd.Series()

# %% [markdown]
# **Setting up Problems**
#
# The utilities provided expect each function to be specified as a list of the following components:
# - Sampling function
# - Validity test
# - Objectives
# - Plotting Range
# - Conditioning Function
# - Condition Value
#
# Unused components can be left as None

# %%
functions=[]

DM_val = load_data.all_val_wrapper()

pareto = np.stack([0.4705*np.linspace(0,1,1000), 0.4705*np.linspace(1,0,1000)], axis=1)
sampling_func_1 = load_data.sample_circle_blobs_wrapper(10000, 6, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples
sampling_func_2 = load_data.sample_circle_blobs_wrapper(10000, 2, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples

rangearr = np.array([[-2,2], [-2,2]])

functions.append([sampling_func_1, DM_val, None, rangearr, None, None])
functions.append([sampling_func_2, DM_val, None, rangearr, None, None])

# %% [markdown]
# **Setting Up Metrics**:
# We set up teh metrics we want to evaluate in a pandas series.
# Each entry consists of:
# metrics["name"] = ["direction", metric wrapper]
#
# - name is a name you are assigning to the metrics
# - direction is either "minimize" or "maximize"
# - metric wrapper is the a wrapper function of the desired metric with any hyperparameters specified

# %%
metrics=pd.Series()
metrics["Nearest Dataset Sample"] = ["minimize", evaluation.gen_data_distance_wrapper("x", "min")]
metrics["Nearest Generated Sample"] = ["minimize", evaluation.data_gen_distance_wrapper("x", "min")]
metrics["F1"] = ["maximize", evaluation.F_wrapper("x", 1)]
metrics["F10"] = ["maximize", evaluation.F_wrapper("x", 10)]
metrics["F0.1"] = ["maximize", evaluation.F_wrapper("x", 0.1)]
metrics["AUC-PR"] = ["maximize", evaluation.AUC_wrapper("x")]
metrics["MMD"] = ["minimize", evaluation.MMD_wrapper("x")]
# Out:
# /tmp/ipykernel_24255/2384849321.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   metrics=pd.Series()

# %% [markdown]
# **General Parameters**
#
# We set up some flags and general settings:

# %%
numgen = 1000 #Number of samples to generate
numinst = 3 #Number of instantiations to test
scaling = True #Scale or not
scorebars = True #Print progress bars for scoring functions

np.random.seed(0)

validity_status = 0 #whether we are considering constraints
obj_status = 0 #whether we are considering functional performance
conditional_status = 0 #whether we are considering conditioning
cond_dist=False #Whether conditional metrics are compared against conditional or marginal distribution

# %% [markdown]
# **fit_and_generate**
# We call fit_and_generate from the utilities file to generate the datasets and train the models.
# fit_and_generate takes:
# - functions: Our list of functions defined earlier
# - methods: Our list of methods defined earlier
# - numinst: How many model instantiations to test
# - numgen: How many points to sample from each generated model
# - scaling: Whether to scale the datasets before training
# - obj_status: #wheteher we are considering functional performance
# - conditional_status: Whether we are considering conditioning
# - holdout: fraction of dataset to hold out during training (used for rediscovery)
#
# The fit_and_generate function returns a timestamp in a string corresponding to the folder in which the results are saved.

# %%
timestr = utils.fit_and_generate(functions, methods, numinst, numgen, scaling, obj_status, conditional_status, 0)
# Out:
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# 2023-02-13 13:40:02.073482: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.090801: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.090998: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.091679: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-13 13:40:02.092754: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.092993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.093187: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.384738: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.384881: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.384985: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-13 13:40:02.385059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21856 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090 Ti, pci bus id: 0000:09:00.0, compute capability: 8.6
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 2023-02-13 13:40:03.676672: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-02-13 13:40:03.677768: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f94c535f600 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-13 13:40:03.677778: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090 Ti, Compute Capability 8.6
# 2023-02-13 13:40:03.680167: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-13 13:40:03.716772: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-02-13 13:40:03.743623: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 79/79 [==============================] - 2s 3ms/step - loss: 0.6571 - reconstruction_loss: 0.2927 - kl_loss: 2.5157
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 79/79 [==============================] - 1s 3ms/step - loss: 0.7163 - reconstruction_loss: 0.3437 - kl_loss: 2.2753
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 79/79 [==============================] - 1s 3ms/step - loss: 0.7186 - reconstruction_loss: 0.3535 - kl_loss: 2.3628
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 79/79 [==============================] - 1s 3ms/step - loss: 0.7222 - reconstruction_loss: 0.3635 - kl_loss: 2.1134
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 79/79 [==============================] - 1s 3ms/step - loss: 0.7430 - reconstruction_loss: 0.3780 - kl_loss: 2.3632
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 79/79 [==============================] - 1s 3ms/step - loss: 0.7622 - reconstruction_loss: 0.4286 - kl_loss: 1.9543

# %% [markdown]
# **score**:
# Next, we score the generated models. The scroring utilities function takes:
# - timestr: the timestring corresponding to the results we want to evaluate
# - functions: Our list of functions defined earlier
# - methods: Our list of methods defined earlier
# - metrics: The metrics to test
# - numinst: How many model instantiations to test
# - scaling: Whether to scale the datasets before training
# - cond_dist: Whether conditional metrics are compared against conditional or marginal distribution
# - scorebars: Whether to print progress bars/ evaluation status
#
# score saves scores in the folder indicated by timestr.

# %%
utils.score(timestr, functions, methods, metrics, numinst, scaling, cond_dist, scorebars)
# Out:
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.09s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.10s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.08s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.07s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.06s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.09s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.16s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:12<00:00,  1.26s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.08s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.17s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.06s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.14s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.07s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:12<00:00,  1.23s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.10s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.08s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.12s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.13s/it]
# Calculating Maximum Mean Discrepancy
# <style type="text/css">
# #T_495d0_row0_col1, #T_495d0_row1_col1, #T_495d0_row2_col1, #T_495d0_row3_col1, #T_495d0_row4_col1, #T_495d0_row5_col1, #T_495d0_row6_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_495d0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 1 Scores:</th>
#       <th id="T_495d0_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_495d0_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_495d0_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_495d0_row0_col0" class="data row0 col0" >0.463±0.030</td>
#       <td id="T_495d0_row0_col1" class="data row0 col1" >0.211±0.014</td>
#     </tr>
#     <tr>
#       <th id="T_495d0_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_495d0_row1_col0" class="data row1 col0" >1.078±0.077</td>
#       <td id="T_495d0_row1_col1" class="data row1 col1" >0.228±0.026</td>
#     </tr>
#     <tr>
#       <th id="T_495d0_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_495d0_row2_col0" class="data row2 col0" >0.008±0.009</td>
#       <td id="T_495d0_row2_col1" class="data row2 col1" >0.146±0.021</td>
#     </tr>
#     <tr>
#       <th id="T_495d0_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_495d0_row3_col0" class="data row3 col0" >0.042±0.014</td>
#       <td id="T_495d0_row3_col1" class="data row3 col1" >0.302±0.011</td>
#     </tr>
#     <tr>
#       <th id="T_495d0_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_495d0_row4_col0" class="data row4 col0" >0.015±0.014</td>
#       <td id="T_495d0_row4_col1" class="data row4 col1" >0.491±0.054</td>
#     </tr>
#     <tr>
#       <th id="T_495d0_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_495d0_row5_col0" class="data row5 col0" >0.001±0.000</td>
#       <td id="T_495d0_row5_col1" class="data row5 col1" >0.068±0.016</td>
#     </tr>
#     <tr>
#       <th id="T_495d0_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_495d0_row6_col0" class="data row6 col0" >0.524±0.010</td>
#       <td id="T_495d0_row6_col1" class="data row6 col1" >0.252±0.014</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_117fa_row0_col1, #T_117fa_row1_col1, #T_117fa_row2_col1, #T_117fa_row3_col1, #T_117fa_row4_col1, #T_117fa_row5_col1, #T_117fa_row6_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_117fa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 2 Scores:</th>
#       <th id="T_117fa_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_117fa_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_117fa_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_117fa_row0_col0" class="data row0 col0" >0.432±0.033</td>
#       <td id="T_117fa_row0_col1" class="data row0 col1" >0.199±0.013</td>
#     </tr>
#     <tr>
#       <th id="T_117fa_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_117fa_row1_col0" class="data row1 col0" >1.022±0.111</td>
#       <td id="T_117fa_row1_col1" class="data row1 col1" >0.236±0.019</td>
#     </tr>
#     <tr>
#       <th id="T_117fa_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_117fa_row2_col0" class="data row2 col0" >0.009±0.012</td>
#       <td id="T_117fa_row2_col1" class="data row2 col1" >0.460±0.067</td>
#     </tr>
#     <tr>
#       <th id="T_117fa_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_117fa_row3_col0" class="data row3 col0" >0.011±0.003</td>
#       <td id="T_117fa_row3_col1" class="data row3 col1" >0.387±0.072</td>
#     </tr>
#     <tr>
#       <th id="T_117fa_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_117fa_row4_col0" class="data row4 col0" >0.078±0.083</td>
#       <td id="T_117fa_row4_col1" class="data row4 col1" >0.799±0.023</td>
#     </tr>
#     <tr>
#       <th id="T_117fa_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_117fa_row5_col0" class="data row5 col0" >0.001±0.002</td>
#       <td id="T_117fa_row5_col1" class="data row5 col1" >0.305±0.056</td>
#     </tr>
#     <tr>
#       <th id="T_117fa_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_117fa_row6_col0" class="data row6 col0" >0.422±0.017</td>
#       <td id="T_117fa_row6_col1" class="data row6 col1" >0.187±0.009</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_39e6b_row0_col1, #T_39e6b_row1_col1, #T_39e6b_row2_col1, #T_39e6b_row3_col1, #T_39e6b_row4_col1, #T_39e6b_row5_col1, #T_39e6b_row6_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_39e6b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Average scores:</th>
#       <th id="T_39e6b_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_39e6b_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39e6b_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_39e6b_row0_col0" class="data row0 col0" >0.448±0.035</td>
#       <td id="T_39e6b_row0_col1" class="data row0 col1" >0.205±0.015</td>
#     </tr>
#     <tr>
#       <th id="T_39e6b_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_39e6b_row1_col0" class="data row1 col0" >1.050±0.099</td>
#       <td id="T_39e6b_row1_col1" class="data row1 col1" >0.232±0.023</td>
#     </tr>
#     <tr>
#       <th id="T_39e6b_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_39e6b_row2_col0" class="data row2 col0" >0.009±0.010</td>
#       <td id="T_39e6b_row2_col1" class="data row2 col1" >0.303±0.165</td>
#     </tr>
#     <tr>
#       <th id="T_39e6b_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_39e6b_row3_col0" class="data row3 col0" >0.027±0.019</td>
#       <td id="T_39e6b_row3_col1" class="data row3 col1" >0.345±0.066</td>
#     </tr>
#     <tr>
#       <th id="T_39e6b_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_39e6b_row4_col0" class="data row4 col0" >0.046±0.067</td>
#       <td id="T_39e6b_row4_col1" class="data row4 col1" >0.645±0.159</td>
#     </tr>
#     <tr>
#       <th id="T_39e6b_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_39e6b_row5_col0" class="data row5 col0" >0.001±0.001</td>
#       <td id="T_39e6b_row5_col1" class="data row5 col1" >0.186±0.126</td>
#     </tr>
#     <tr>
#       <th id="T_39e6b_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_39e6b_row6_col0" class="data row6 col0" >0.473±0.053</td>
#       <td id="T_39e6b_row6_col1" class="data row6 col1" >0.220±0.034</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **plot_all**:
# Next, we plot the generated distributions. The plotting function takes:
#
# - timestr: the timestring corresponding to the results we want to evaluate
# - functions: Our list of functions defined earlier
# - methods: Our list of methods defined earlier
# - numinst: How many model instantiations to test
# - scaling: Whether to scale the datasets before training
# - validity_status:whether we are considering constraints
# - obj_status: whether we are considering functional performance
# - conditional_status: whether we are considering conditioning
# - cond_dist: Whether conditional metrics are compared against conditional or marginal distribution
#
# plot saves plots in the folder indicated by timestr. If numinst is greater than 1, saves an animation of the plots

# %%
utils.plot_all(timestr, functions, methods, numinst, scaling, validity_status, obj_status, conditional_status, cond_dist, "red")
# Out:
# 0
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# /home/mileva/mambaforge/envs/tf/lib/python3.10/site-packages/PIL/Image.py:3167: DecompressionBombWarning: Image size (91068800 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %% [markdown]
# **Special Metrics**
#
# When working with a few special types of metrics we must do some special setup. For rediscovery, we must designate a holdout fraction which we pass to fit_and_generate. For ML efficacy, we must include an auxiliary predictive task. In this case, we encode this predictive task in an objective function. Objectives are also used when considering performance attributes of designs.

# %%
#Rediscovery needs special handling in the utils file. 
#We pass in a special flag: "Rediscovery" to trigger this handling. See utils file for more info
metrics["Rediscovery"] = ["minimize", "Rediscovery", evaluation.data_gen_distance_wrapper("x", "min")]
holdout = 0.05 #If using rediscovery, we need to hold out a portion of the data during training

from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import r2_score

metrics["ML Efficacy"] = ["maximize", evaluation.ML_efficacy_wrapper(KNeighborsRegressor(n_neighbors=5), r2_score)]

# %%
print(metrics)
# Out:
# Nearest Dataset Sample      [minimize, <function gen_data_distance_wrapper...
# Nearest Generated Sample    [minimize, <function data_gen_distance_wrapper...
# F1                          [maximize, <function F_wrapper.<locals>.calc_p...
# F10                         [maximize, <function F_wrapper.<locals>.calc_p...
# F0.1                        [maximize, <function F_wrapper.<locals>.calc_p...
# AUC-PR                      [maximize, <function AUC_wrapper.<locals>.calc...
# MMD                         [minimize, <function MMD_wrapper.<locals>.MMD ...
# Rediscovery                 [minimize, Rediscovery, <function data_gen_dis...
# ML Efficacy                 [maximize, <function ML_efficacy_wrapper.<loca...
# dtype: object

# %%
functions=[]

DM_val = load_data.all_val_wrapper()

#In this case, we include objectives specifically for ML efficacy
DM_objs = [load_data.KNO1_a_wrapper(4,4), load_data.KNO1_b_wrapper(4,4)] 

pareto = np.stack([0.4705*np.linspace(0,1,1000), 0.4705*np.linspace(1,0,1000)], axis=1)
sampling_func_1 = load_data.sample_circle_blobs_wrapper(10000, 6, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples
sampling_func_2 = load_data.sample_circle_blobs_wrapper(10000, 2, 1.3, 0.22) #Uniform Sampling with Number of positive samples & Negative Samples

rangearr = np.array([[-2,2], [-2,2]])

functions.append([sampling_func_1, DM_val, DM_objs, rangearr, None, None])
functions.append([sampling_func_2, DM_val, DM_objs, rangearr, None, None])

# %%
timestr = utils.fit_and_generate(functions, methods, numinst, numgen, scaling, obj_status, conditional_status, holdout)
# Out:
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 75/75 [==============================] - 1s 2ms/step - loss: 0.7523 - reconstruction_loss: 0.3852 - kl_loss: 2.2514
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 75/75 [==============================] - 1s 3ms/step - loss: 0.7137 - reconstruction_loss: 0.3693 - kl_loss: 2.3174
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 75/75 [==============================] - 1s 3ms/step - loss: 0.7230 - reconstruction_loss: 0.3533 - kl_loss: 2.3364
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 75/75 [==============================] - 1s 3ms/step - loss: 0.7399 - reconstruction_loss: 0.3681 - kl_loss: 2.1855
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 75/75 [==============================] - 1s 3ms/step - loss: 0.7169 - reconstruction_loss: 0.3518 - kl_loss: 2.4777
# 0
# Lambda1 set to 0, DPP loss disabled; Ignoring CLF and REG...
# GAN Training::   0%|          | 0/5 [00:00<?, ?it/s]
# 75/75 [==============================] - 2s 3ms/step - loss: 0.7555 - reconstruction_loss: 0.3965 - kl_loss: 2.1522

# %%
utils.score(timestr, functions, methods, metrics, numinst, scaling, cond_dist, scorebars)
# Out:
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.01s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.06s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.11s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.17s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.12s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.11s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.09s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.09s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.12s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.15s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.04s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.16s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.06s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.06s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.14s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.20s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.09s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:09<00:00,  1.01it/s]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.02s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.07s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.06s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:11<00:00,  1.16s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.10s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# Calculating Gen-Data Distance
# Calculating Data-Gen Distance
# Calculating F1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.05s/it]
# Calculating F10
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.08s/it]
# Calculating F0.1
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.03s/it]
# Calculating AUC
# Calculating Precision/Recall:: 100%|============| 10/10 [00:10<00:00,  1.10s/it]
# Calculating Maximum Mean Discrepancy
# Calculating Data-Gen Distance
# Calculating ML Efficacy
# <style type="text/css">
# #T_9f6eb_row0_col1, #T_9f6eb_row1_col1, #T_9f6eb_row2_col1, #T_9f6eb_row3_col1, #T_9f6eb_row4_col1, #T_9f6eb_row5_col1, #T_9f6eb_row6_col1, #T_9f6eb_row7_col1, #T_9f6eb_row8_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_9f6eb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 1 Scores:</th>
#       <th id="T_9f6eb_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_9f6eb_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f6eb_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_9f6eb_row0_col0" class="data row0 col0" >0.524±0.046</td>
#       <td id="T_9f6eb_row0_col1" class="data row0 col1" >0.242±0.006</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_9f6eb_row1_col0" class="data row1 col0" >1.101±0.072</td>
#       <td id="T_9f6eb_row1_col1" class="data row1 col1" >0.222±0.036</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_9f6eb_row2_col0" class="data row2 col0" >0.000±0.000</td>
#       <td id="T_9f6eb_row2_col1" class="data row2 col1" >0.129±0.026</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_9f6eb_row3_col0" class="data row3 col0" >0.012±0.009</td>
#       <td id="T_9f6eb_row3_col1" class="data row3 col1" >0.308±0.024</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_9f6eb_row4_col0" class="data row4 col0" >0.000±0.000</td>
#       <td id="T_9f6eb_row4_col1" class="data row4 col1" >0.506±0.080</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_9f6eb_row5_col0" class="data row5 col0" >0.000±0.000</td>
#       <td id="T_9f6eb_row5_col1" class="data row5 col1" >0.063±0.019</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_9f6eb_row6_col0" class="data row6 col0" >0.532±0.010</td>
#       <td id="T_9f6eb_row6_col1" class="data row6 col1" >0.257±0.020</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row7" class="row_heading level0 row7" >Rediscovery</th>
#       <td id="T_9f6eb_row7_col0" class="data row7 col0" >0.996±0.053</td>
#       <td id="T_9f6eb_row7_col1" class="data row7 col1" >0.165±0.030</td>
#     </tr>
#     <tr>
#       <th id="T_9f6eb_level0_row8" class="row_heading level0 row8" >ML Efficacy</th>
#       <td id="T_9f6eb_row8_col0" class="data row8 col0" >-0.655±0.156</td>
#       <td id="T_9f6eb_row8_col1" class="data row8 col1" >0.398±0.179</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_45ec2_row0_col1, #T_45ec2_row1_col1, #T_45ec2_row2_col1, #T_45ec2_row3_col1, #T_45ec2_row4_col1, #T_45ec2_row5_col1, #T_45ec2_row6_col1, #T_45ec2_row7_col1, #T_45ec2_row8_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_45ec2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Problem 2 Scores:</th>
#       <th id="T_45ec2_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_45ec2_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45ec2_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_45ec2_row0_col0" class="data row0 col0" >0.402±0.039</td>
#       <td id="T_45ec2_row0_col1" class="data row0 col1" >0.206±0.003</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_45ec2_row1_col0" class="data row1 col0" >0.989±0.058</td>
#       <td id="T_45ec2_row1_col1" class="data row1 col1" >0.265±0.009</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_45ec2_row2_col0" class="data row2 col0" >0.004±0.004</td>
#       <td id="T_45ec2_row2_col1" class="data row2 col1" >0.406±0.032</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_45ec2_row3_col0" class="data row3 col0" >0.013±0.003</td>
#       <td id="T_45ec2_row3_col1" class="data row3 col1" >0.340±0.038</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_45ec2_row4_col0" class="data row4 col0" >0.070±0.071</td>
#       <td id="T_45ec2_row4_col1" class="data row4 col1" >0.783±0.017</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_45ec2_row5_col0" class="data row5 col0" >0.001±0.001</td>
#       <td id="T_45ec2_row5_col1" class="data row5 col1" >0.259±0.031</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_45ec2_row6_col0" class="data row6 col0" >0.416±0.007</td>
#       <td id="T_45ec2_row6_col1" class="data row6 col1" >0.195±0.007</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row7" class="row_heading level0 row7" >Rediscovery</th>
#       <td id="T_45ec2_row7_col0" class="data row7 col0" >0.991±0.049</td>
#       <td id="T_45ec2_row7_col1" class="data row7 col1" >0.232±0.049</td>
#     </tr>
#     <tr>
#       <th id="T_45ec2_level0_row8" class="row_heading level0 row8" >ML Efficacy</th>
#       <td id="T_45ec2_row8_col0" class="data row8 col0" >-1.328±0.296</td>
#       <td id="T_45ec2_row8_col1" class="data row8 col1" >0.266±0.058</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b0046_row0_col1, #T_b0046_row1_col1, #T_b0046_row2_col1, #T_b0046_row3_col1, #T_b0046_row4_col1, #T_b0046_row5_col1, #T_b0046_row6_col1, #T_b0046_row7_col1, #T_b0046_row8_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_b0046">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Average scores:</th>
#       <th id="T_b0046_level0_col0" class="col_heading level0 col0" >GAN</th>
#       <th id="T_b0046_level0_col1" class="col_heading level0 col1" >VAE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0046_level0_row0" class="row_heading level0 row0" >Nearest Dataset Sample</th>
#       <td id="T_b0046_row0_col0" class="data row0 col0" >0.463±0.075</td>
#       <td id="T_b0046_row0_col1" class="data row0 col1" >0.224±0.019</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row1" class="row_heading level0 row1" >Nearest Generated Sample</th>
#       <td id="T_b0046_row1_col0" class="data row1 col0" >1.045±0.086</td>
#       <td id="T_b0046_row1_col1" class="data row1 col1" >0.244±0.034</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_b0046_row2_col0" class="data row2 col0" >0.002±0.003</td>
#       <td id="T_b0046_row2_col1" class="data row2 col1" >0.268±0.141</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row3" class="row_heading level0 row3" >F10</th>
#       <td id="T_b0046_row3_col0" class="data row3 col0" >0.013±0.006</td>
#       <td id="T_b0046_row3_col1" class="data row3 col1" >0.324±0.035</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row4" class="row_heading level0 row4" >F0.1</th>
#       <td id="T_b0046_row4_col0" class="data row4 col0" >0.035±0.061</td>
#       <td id="T_b0046_row4_col1" class="data row4 col1" >0.645±0.150</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row5" class="row_heading level0 row5" >AUC-PR</th>
#       <td id="T_b0046_row5_col0" class="data row5 col0" >0.000±0.001</td>
#       <td id="T_b0046_row5_col1" class="data row5 col1" >0.161±0.102</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row6" class="row_heading level0 row6" >MMD</th>
#       <td id="T_b0046_row6_col0" class="data row6 col0" >0.474±0.059</td>
#       <td id="T_b0046_row6_col1" class="data row6 col1" >0.226±0.034</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row7" class="row_heading level0 row7" >Rediscovery</th>
#       <td id="T_b0046_row7_col0" class="data row7 col0" >0.993±0.051</td>
#       <td id="T_b0046_row7_col1" class="data row7 col1" >0.198±0.053</td>
#     </tr>
#     <tr>
#       <th id="T_b0046_level0_row8" class="row_heading level0 row8" >ML Efficacy</th>
#       <td id="T_b0046_row8_col0" class="data row8 col0" >-0.992±0.411</td>
#       <td id="T_b0046_row8_col1" class="data row8 col1" >0.332±0.149</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Other Use Cases**
#
# In this notebook, we have demonstrated how to evaluate numerous models on numerous problems in a distribution-matching setting. To evaluate models for other types of problems, such as diversity, constraint satisfaction, performance, and conditioning, please refer to Notebook 3.
